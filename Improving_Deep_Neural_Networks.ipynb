# %%
from IPython import display

# %% [markdown]
# # Train / Dev / Test sets
#
# ## Setting up  Machine Learning Application

# %%
display.Image("/Users/vinod/Desktop/Programming/improving_Deep_Neural_Networks/ML#1.png")

# %%
display.Image("/Users/vinod/Desktop/Programming/improving_Deep_Neural_Networks/ML#2.png")

# %% [markdown]
# # Bias / Variance

# %%
display.Image("/Users/vinod/Desktop/Programming/improving_Deep_Neural_Networks/ML#3.png")

# %%
display.Image("/Users/vinod/Desktop/Programming/improving_Deep_Neural_Networks/ML#4.png")
